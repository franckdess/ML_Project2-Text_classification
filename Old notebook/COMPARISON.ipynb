# %%
from matplotlib import pyplot as plt

# %%
log_reg = [82.7725, 84.6, 84.5825, 84.995, 84.775, 84.515]
sgd = [81.75, 82.5425, 82.5875, 82.9475, 82.645, 82.335]
linearSVC = [82.58, 84.19, 84.04, 84.22, 84.115, 84.0475]

n_range = [1, 2, 3, 4, 5, 6]

# %%
plt.figure(figsize=(15, 7.5))
plt.plot(n_range, log_reg, color='red', label='Logistic regression')
plt.plot(n_range, sgd, color='orange', label='SGDClassifier')
plt.plot(n_range, linearSVC, color='lightgreen', label='LinearSVC')
plt.ylim((81, 86))
plt.grid(True)
plt.xlabel('Upper bound for ngram_range')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
is_ = [1000, 2000, 3000, 4000, 5000, 6000, 8000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 60000, 80000, 100000]

# %%
accLOGREG=  [71.79, 74.58, 75.98, 77.16, 77.97, 78.33, 78.94, 79.53, 80.64, 81.07, 81.75, 82, 82.33, 82.66, 83.34, 83.81, 84.18]
accSGD =    [72.7, 75.48, 76.49, 76.99, 77.66, 78.37, 79.75, 80.37, 81.33, 81.56, 81.85, 81.98, 82.03, 82.17, 82.31, 82.32, 82.38]
accLINSVC = [74.29, 76.20, 77.42, 78.27, 78.88, 79.18, 79.72, 80.15, 80.97, 81.32, 81.69, 81.97, 82.21, 82.44, 83.02, 83.12, 83.59]
accSVC =    [73.53, 75.86, 77.03, 77.88, 78.42, 79.08, 79.57, 80.16, 80.92, 81.3, 82.02, 82.2, 82.67, 82.89, 83.64, 84.10, 84.3]

# %%
plt.figure(figsize=(15, 7.5))
plt.plot(is_, accLOGREG, label='Logistic Regression', color='lightgreen')
plt.plot(is_, accSGD, label='SGDClassifier', color='lightblue')
plt.plot(is_, accLINSVC, label='LinearSVC', color='orange')
plt.plot(is_, accSVC, label='SVC', color='red')
plt.xlabel('Number of samples')
plt.ylabel('Accuracy')
plt.grid()
plt.ylim((75, 85))
plt.legend()
plt.show()
